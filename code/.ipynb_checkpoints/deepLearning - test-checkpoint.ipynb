# %%
import pandas as pd
# Out:
# C:\Users\Mayur\AppData\Local\Temp\ipykernel_13208\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
lie_data = pd.read_csv('.\previous-MLcode\lie_dataset.csv')
lie_data.head()
# Out:
#       lipsx     lipsy  left_browx  left_browy  right_browx  right_browy  \
# 0 -0.001107  0.031804   -0.053075   -0.033591     0.060648    -0.029370
# 1 -0.001794  0.030796   -0.052959   -0.032074     0.059244    -0.029025
# 2 -0.002718  0.031074   -0.054027   -0.032401     0.058203    -0.028548
# 3 -0.002734  0.031018   -0.053086   -0.032754     0.059224    -0.028536
# 4 -0.002798  0.030957   -0.052412   -0.032349     0.058886    -0.028198
#
#      body0x    body0y    body1x    body1y  ...    body7y    face0x    face0y  \
# 0  0.244749 -0.003385 -0.244749  0.003385  ...  0.544281  0.008663 -0.040341
# 1  0.246057 -0.003136 -0.246057  0.003136  ...  0.544409  0.007592 -0.037885
# 2  0.246974 -0.002954 -0.246974  0.002954  ...  0.545489  0.006395 -0.037179
# 3  0.247235 -0.002925 -0.247235  0.002925  ...  0.545792  0.007735 -0.037539
# 4  0.247395 -0.002847 -0.247395  0.002847  ...  0.545749  0.007852 -0.037106
#
#      face1x    face1y    face2x    face2y    face3x    face3y  TRUTH
# 0 -0.004295  0.063091 -0.080905  0.017946  0.079827  0.023363      1
# 1 -0.004266  0.061061 -0.079106  0.019367  0.077311  0.023393      1
# 2 -0.006021  0.060508 -0.081213  0.019012  0.075062  0.023403      1
# 3 -0.006494  0.060074 -0.080609  0.018408  0.075682  0.023359      1
# 4 -0.006559  0.060057 -0.080242  0.018465  0.075385  0.023527      1
#
# [5 rows x 31 columns]

# %%
X = lie_data.copy()
y = X.pop("TRUTH")

input_shape = X.shape[1]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, stratify=y, train_size=0.6)

# %%
from tensorflow import keras
from tensorflow.keras import layers
# Out:
# WARNING:tensorflow:From N:\Mayur\Programming\GitHub\lie-detection\code\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=[input_shape]),
    layers.Dropout(0.4),
    layers.Dense(32, activation='relu'),
    layers.Dropout(0.4),
    layers.Dense(1, activation='sigmoid'),
])
# Out:
# WARNING:tensorflow:From N:\Mayur\Programming\GitHub\lie-detection\code\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.compile(
    optimizer = "adam",
    loss="binary_crossentropy",
    metrics=['binary_accuracy']
)
# Out:
# WARNING:tensorflow:From N:\Mayur\Programming\GitHub\lie-detection\code\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=20,
    min_delta=0.0000000001,
    restore_best_weights=True,
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=200,
    epochs=200,
    callbacks=[early_stopping],
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy", xlim=[0,1], ylim=[0,1])
# Out:
# Epoch 1/200
# 1/1 [==============================] - 0s 138ms/step - loss: 0.6961 - binary_accuracy: 0.5132 - val_loss: 0.6925 - val_binary_accuracy: 0.5159
# Epoch 2/200
# 1/1 [==============================] - 0s 69ms/step - loss: 0.6877 - binary_accuracy: 0.5397 - val_loss: 0.6925 - val_binary_accuracy: 0.5159
# Epoch 3/200
# 1/1 [==============================] - 0s 72ms/step - loss: 0.6950 - binary_accuracy: 0.5132 - val_loss: 0.6925 - val_binary_accuracy: 0.5159
# Epoch 4/200
# 1/1 [==============================] - 0s 84ms/step - loss: 0.6978 - binary_accuracy: 0.4709 - val_loss: 0.6925 - val_binary_accuracy: 0.5159
# Epoch 5/200
# 1/1 [==============================] - 0s 104ms/step - loss: 0.6891 - binary_accuracy: 0.5026 - val_loss: 0.6925 - val_binary_accuracy: 0.5159
# Epoch 6/200
# 1/1 [==============================] - 0s 86ms/step - loss: 0.6890 - binary_accuracy: 0.5503 - val_loss: 0.6925 - val_binary_accuracy: 0.5159
# Epoch 7/200
# 1/1 [==============================] - 0s 71ms/step - loss: 0.6956 - binary_accuracy: 0.5026 - val_loss: 0.6925 - val_binary_accuracy: 0.5159
# Epoch 8/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.6907 - binary_accuracy: 0.5450 - val_loss: 0.6925 - val_binary_accuracy: 0.5159
# Epoch 9/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.6891 - binary_accuracy: 0.5450 - val_loss: 0.6925 - val_binary_accuracy: 0.5159
# Epoch 10/200
# 1/1 [==============================] - 0s 60ms/step - loss: 0.6935 - binary_accuracy: 0.4921 - val_loss: 0.6925 - val_binary_accuracy: 0.5159
# Epoch 11/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.6856 - binary_accuracy: 0.5873 - val_loss: 0.6925 - val_binary_accuracy: 0.5159
# Epoch 12/200
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6955 - binary_accuracy: 0.5132 - val_loss: 0.6925 - val_binary_accuracy: 0.5159
# Epoch 13/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.6923 - binary_accuracy: 0.5132 - val_loss: 0.6925 - val_binary_accuracy: 0.5159
# Epoch 14/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.6959 - binary_accuracy: 0.4709 - val_loss: 0.6925 - val_binary_accuracy: 0.5159
# Epoch 15/200
# 1/1 [==============================] - 0s 60ms/step - loss: 0.6947 - binary_accuracy: 0.5079 - val_loss: 0.6924 - val_binary_accuracy: 0.5159
# Epoch 16/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.6915 - binary_accuracy: 0.4868 - val_loss: 0.6924 - val_binary_accuracy: 0.5159
# Epoch 17/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.6868 - binary_accuracy: 0.5026 - val_loss: 0.6924 - val_binary_accuracy: 0.5159
# Epoch 18/200
